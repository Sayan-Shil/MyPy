# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Titanic.csv')

# %%
df.set_index('Ticket_ID', inplace=True)
df
# Out:
#                            Name   Age Class    Fare Survived
# Ticket_ID
# 1001                  John Smith   34     A  120000      Yes
# 1002             William Johnson   32     C  480000       No
# 1003              James Williams   34     D  360000       No
# 1004                George Brown   21     C  500000      Yes
# 1005              Charles Garcia   25     A  250000      Yes
# 1006                 Henry Davis   65     B  120000      Yes
# 1007             Thomas Martinez   64     C  480000       No
# 1008            Joseph Rodriguez   45     B  360000       No
# 1009               Robert Miller   32     C  360000       No
# 1010               Michael Jones   25     B  250000       No
# 1011                David Taylor   24     D  500000       No
# 1012               Richard Moore   45     B  120000       No
# 1013             Edward Anderson   51     B  250000      Yes
# 1014               Daniel Thomas   21     C  500000      Yes
# ...

# %%
# delete column

# %%
df.drop("Class")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df.drop("Class")
#
# File d:\Python For  Project\Pandas\.venv\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# ...

# %%
# this will give erroe bcz by default axis=0 means rows and there is no "Class" type in axis 1
df.drop("Class",axis=1)

# %%
#delete row

# %%
df.drop(1016)

# %%
df

# %%
#You have see the changes are not permanent, to do permananent changes inplace=True must be apply

# %%
df
# Out:
#                       Name   Age    Fare Survived
# Ticket_ID
# 1001             John Smith   34  120000      Yes
# 1002        William Johnson   32  480000       No
# 1003         James Williams   34  360000       No
# 1004           George Brown   21  500000      Yes
# 1005         Charles Garcia   25  250000      Yes
# 1006            Henry Davis   65  120000      Yes
# 1007        Thomas Martinez   64  480000       No
# 1008       Joseph Rodriguez   45  360000       No
# 1009          Robert Miller   32  360000       No
# 1010          Michael Jones   25  250000       No
# 1011           David Taylor   24  500000       No
# 1012          Richard Moore   45  120000       No
# 1013        Edward Anderson   51  250000      Yes
# 1014          Daniel Thomas   21  500000      Yes
# 1015          Anthony White   29  360000       No
