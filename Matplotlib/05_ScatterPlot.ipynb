# %%
import numpy as np
import pandas as pd

# %%
columns = ['Item', 'Price', 'Quantity', 'Revenue', 'Discount', 'Net Profit']
data = {
    'Item': ['Apple', 'Banana', 'Carrot', 'Dates', 'Eggplant', 'Fig', 'Grapes', 'Honeydew', 
             'Ivy Gourd', 'Jackfruit', 'Kiwi', 'Lemon', 'Mango', 'Nectarine', 'Orange', 
             'Papaya', 'Quince', 'Raspberry', 'Strawberry', 'Tomato'],
    'Price': np.random.uniform(10, 100, 20),
    'Quantity': np.random.randint(1, 50, 20),
    'Revenue': np.random.uniform(500, 5000, 20),
    'Discount': np.random.uniform(0, 30, 20),
    'Net Profit': np.random.uniform(50, 1000, 20)
}

df = pd.DataFrame(data)
df
# Out:
#           Item      Price  Quantity      Revenue   Discount  Net Profit
# 0        Apple  89.568958        44  4007.802962   0.135424  626.672984
# 1       Banana  14.842765        16  1621.358495  12.168119  443.232176
# 2       Carrot  53.982863        38  2486.939958  22.479070  321.805350
# 3        Dates  98.416765        27  1910.096516   7.437834  201.856838
# 4     Eggplant  27.852405         5  2541.203156   4.735179   96.560654
# 5          Fig  54.165994        35   546.342721  12.136787  663.276620
# 6       Grapes  21.855527        23  2558.476504  15.238436  443.371958
# 7     Honeydew  47.124254        17  4684.944077  15.688259  918.524197
# 8    Ivy Gourd  40.830030        46  2043.118734  24.813764  974.752197
# 9    Jackfruit  12.227944        42  3623.995290  19.554715  705.522956
# 10        Kiwi  24.332920        38  1358.819464   5.637121  920.088611
# 11       Lemon  32.092129        45  3270.644263  19.691093  252.910907
# 12       Mango  98.615446        49  3636.346603  10.941834  893.779511
# 13   Nectarine  68.745848        32  3674.881085   5.469122  266.718083
# 14      Orange  15.815821        15  3139.036834   4.506314  275.963838
# 15      Papaya  34.023777        26  4835.295354  16.875349  241.024429
# 16      Quince  32.687954         2   805.479585  13.022692  519.226561
# 17   Raspberry  44.056230        12  3547.621688   1.301760  192.752065
# 18  Strawberry  37.738821        37  2995.900506  27.859963  307.734991
# 19      Tomato  38.755299        34  1338.355344  13.001738  565.615804

# %%
df.plot(kind="scatter", x="Revenue"  , y="Net Profit")
# Out:
# <Axes: xlabel='Revenue', ylabel='Net Profit'>

# %%
df2 = pd.DataFrame(np.random.choice(range(1, 101), size=(500, 5)))
df2.columns = ["Maths", "Physics", "Biology", "Chemistry", "Language"]
df2
# Out:
#      Maths  Physics  Biology  Chemistry  Language
# 0       43       72       50         60        44
# 1       59       80       71         65         1
# 2       86       72       21          9        82
# 3       19       55       83         61        90
# 4       51       24       28         52        24
# ..     ...      ...      ...        ...       ...
# 495      6       75      100         58        37
# 496     87       43        2         58        32
# 497     18       14       93         61        96
# 498     55       67        6         60        81
# 499     44       43       91         97        72
#
# [500 rows x 5 columns]

# %%
df2.plot(kind="scatter", x="Maths"  , y="Physics", c="Chemistry" , cmap="Greens")
# Out:
# <Axes: xlabel='Maths', ylabel='Physics'>

# %%
df2.plot(kind="scatter", x="Maths"  , y="Physics", s=df2.Chemistry*2 , alpha=0.1)
# Out:
# <Axes: xlabel='Maths', ylabel='Physics'>
