# %%
import numpy as np
import pandas as pd

# %%
columns = ['Item', 'Price', 'Quantity', 'Revenue', 'Discount', 'Net Profit']
data = {
    'Item': ['Apple', 'Banana', 'Carrot', 'Dates', 'Eggplant', 'Fig', 'Grapes', 'Honeydew', 
             'Ivy Gourd', 'Jackfruit', 'Kiwi', 'Lemon', 'Mango', 'Nectarine', 'Orange', 
             'Papaya', 'Quince', 'Raspberry', 'Strawberry', 'Tomato'],
    'Price': np.random.uniform(10, 100, 20),
    'Quantity': np.random.randint(1, 50, 20),
    'Revenue': np.random.uniform(500, 5000, 20),
    'Discount': np.random.uniform(0, 30, 20),
    'Net Profit': np.random.uniform(50, 1000, 20)
}

df = pd.DataFrame(data)
df
# Out:
#           Item      Price  Quantity      Revenue   Discount  Net Profit
# 0        Apple  40.945572         4  1976.624282  18.890680  823.426031
# 1       Banana  14.465080         9  1662.143791   1.453254  202.939018
# 2       Carrot  94.716511        14   816.683816   6.675297  801.093444
# 3        Dates  28.680401        43  1747.373532  21.346568  440.297070
# 4     Eggplant  80.413507         4  1802.877782  26.204313  709.841154
# 5          Fig  67.999771        36  2818.666991  20.712841  448.569092
# 6       Grapes  38.759041        48  3705.985998  12.021610  397.306692
# 7     Honeydew  16.344451        43  2179.644743  12.924496  378.071816
# 8    Ivy Gourd  85.609596         2  4916.457506   9.078257  987.717842
# 9    Jackfruit  91.276363        16  2544.402851   7.218449  963.944344
# 10        Kiwi  11.233103        45  1292.435672  11.685718  959.748232
# 11       Lemon  51.948987        38  3136.326657  21.316025  991.743038
# 12       Mango  24.719786        16  3008.501857   9.996036  256.198851
# 13   Nectarine  34.688012        47  3771.802210  27.391689  735.097227
# 14      Orange  37.868622         3  2602.384890   5.935955  873.749515
# 15      Papaya  64.478768         3   818.800671  11.446057  874.544848
# 16      Quince  23.155062        49  4165.944398  26.722611  462.449292
# 17   Raspberry  38.580683        24  1668.952697  15.146248  978.421997
# 18  Strawberry  57.165567        35  4614.977476  17.839742  104.607935
# 19      Tomato  42.689349        21  3521.288698  18.595868   50.992688

# %%
# Implement Bar Chart
df.plot(kind='bar', color=['red','yellow','Orange','green','blue'], width=1.2 , figsize=(10,5))
# Out:
# <Axes: >

# %%
df.plot(kind='bar', stacked=True, color=['red','yellow','Orange','green','blue'])
# Out:
# <Axes: >
