# %%
import numpy as np
import pandas as pd

# %%
columns = ['Item', 'Price', 'Quantity', 'Revenue', 'Discount', 'Net Profit']
data = {
    'Item': ['Apple', 'Banana', 'Carrot', 'Dates', 'Eggplant', 'Fig', 'Grapes', 'Honeydew', 
             'Ivy Gourd', 'Jackfruit', 'Kiwi', 'Lemon', 'Mango', 'Nectarine', 'Orange', 
             'Papaya', 'Quince', 'Raspberry', 'Strawberry', 'Tomato'],
    'Price': np.random.uniform(10, 100, 20),
    'Quantity': np.random.randint(1, 50, 20),
    'Revenue': np.random.uniform(500, 5000, 20),
    'Discount': np.random.uniform(0, 30, 20),
    'Net Profit': np.random.uniform(50, 1000, 20)
}

df = pd.DataFrame(data)
df
# Out:
#           Item      Price  Quantity      Revenue   Discount  Net Profit
# 0        Apple  99.266640        24  4868.612522  19.541258  939.016480
# 1       Banana  82.866791        23  2392.206579  16.738747  890.953426
# 2       Carrot  78.275286        45   809.890976  15.906623   81.501194
# 3        Dates  25.146968        27  3800.054990   9.195213  871.806264
# 4     Eggplant  11.515483         5  1983.875177  29.766477  740.289030
# 5          Fig  37.741990        18  2244.086304  29.927743  358.065085
# 6       Grapes  51.531345        22   693.012638  29.131244  290.543212
# 7     Honeydew  92.547579        35  1193.680728  16.110465  176.911965
# 8    Ivy Gourd  38.399384         9  4024.903598  17.974334  187.215551
# 9    Jackfruit  73.089381         8  2116.933387  13.157627  165.865738
# 10        Kiwi  15.270675        33  1828.690881  27.124929  750.168492
# 11       Lemon  99.162215        11  3337.402031   0.807686  203.549588
# 12       Mango  85.436812         1  4283.852611  18.825731  524.929838
# 13   Nectarine  67.151498         5  1486.305786  23.467289   90.903675
# 14      Orange  84.818618        16  1243.564133  13.886455  184.075609
# 15      Papaya  40.415580        34  2715.519451  24.309005  168.833012
# 16      Quince  16.002420        15  1334.768480  24.063369   54.604005
# 17   Raspberry  60.829661         1  1267.242867  11.628563  641.056362
# 18  Strawberry  41.219116        21  4086.307966  13.611046  125.993348
# 19      Tomato  56.885447        22   799.676757  15.303379  597.568835

# %%
# Area gives a areal distributic view of  from data-table

# %%
df.plot(kind='area',stacked=True)
# Out:
# <Axes: >

# %%
df.plot(kind='area', alpha=0.5) # this will eventually lower the opacity of colour
# Out:
# <Axes: >

# %%
df.plot(kind='area', table=True )
# Out:
# <Axes: >

# %%
df.plot(kind='area', alpha=0.5, title="Graph", figsize=(10,5))
# Out:
# <Axes: title={'center': 'Graph'}>

# %%
#  Plot only 1 Column Area Graph:

# %%
df.Price.plot(kind='area', color='Orange', title="Graph", grid=True)
# Out:
# <Axes: title={'center': 'Graph'}>
