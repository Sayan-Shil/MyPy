# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
# matplotlib is a Python Library Function that is used for data visualization

# %%
columns = ['Item', 'Price', 'Quantity', 'Revenue', 'Discount', 'Net Profit']
data = {
    'Item': ['Apple', 'Banana', 'Carrot', 'Dates', 'Eggplant', 'Fig', 'Grapes', 'Honeydew', 
             'Ivy Gourd', 'Jackfruit', 'Kiwi', 'Lemon', 'Mango', 'Nectarine', 'Orange', 
             'Papaya', 'Quince', 'Raspberry', 'Strawberry', 'Tomato'],
    'Price': np.random.uniform(10, 100, 20),
    'Quantity': np.random.randint(1, 50, 20),
    'Revenue': np.random.uniform(500, 5000, 20),
    'Discount': np.random.uniform(0, 30, 20),
    'Net Profit': np.random.uniform(50, 1000, 20)
}

df = pd.DataFrame(data)
df
# Out:
#           Item      Price  Quantity      Revenue   Discount  Net Profit
# 0        Apple  45.323592        39   984.542865   3.201017  414.563063
# 1       Banana  11.090031        18  3672.057159  17.524632  185.225333
# 2       Carrot  73.928519        22  2554.629601  16.312237  749.961651
# 3        Dates  24.991534        49  3218.168336  22.654905  100.623686
# 4     Eggplant  48.237354        17  4141.359192   8.283679  725.261932
# 5          Fig  66.037034        29   502.281745   9.638356  651.983392
# 6       Grapes  95.100025        26  4641.433913  28.678601  760.506184
# 7     Honeydew  58.242971        15  4638.179919  16.391934  534.233135
# 8    Ivy Gourd  21.894309        39  2082.768925   9.045992  282.030613
# 9    Jackfruit  39.415831        26  2580.850304  21.068147  355.854931
# 10        Kiwi  50.006925        26  4504.498718  28.879895  892.741406
# 11       Lemon  47.639043        12  4490.071759  24.799814  403.156467
# 12       Mango  52.281460        37  4266.041739  16.169469  290.781264
# 13   Nectarine  23.082911        45  3051.668471   4.744904   96.713458
# 14      Orange  50.667492        35  1896.388154  17.321464  148.444567
# 15      Papaya  38.663173        12  2880.821464   4.590807  890.582853
# 16      Quince  30.515774        33  1327.232770   6.470394  300.548700
# 17   Raspberry  55.671053        24  4074.861428  25.906138  911.355393
# 18  Strawberry  77.882464        37   526.079499   7.276062  766.614573
# 19      Tomato  96.601561        42   584.041523   7.537412  178.552793

# %%
df["Price"].hist()
# Out:
# <Axes: >

# %%
df["Price"].hist(bins=20)
# Out:
# <Axes: >

# %%
df["Price"].hist(grid=False)
# Out:
# <Axes: >

# %%
df["Price"].hist(legend=True)
# Out:
# <Axes: >

# %%
df[["Price","Discount"]].hist(legend=True, color='grey')
# Out:
# array([[<Axes: title={'center': 'Price'}>,
#         <Axes: title={'center': 'Discount'}>]], dtype=object)

# %%
df.hist(legend=True)
# Out:
# array([[<Axes: title={'center': 'Price'}>,
#         <Axes: title={'center': 'Quantity'}>],
#        [<Axes: title={'center': 'Revenue'}>,
#         <Axes: title={'center': 'Discount'}>],
#        [<Axes: title={'center': 'Net Profit'}>, <Axes: >]], dtype=object)
